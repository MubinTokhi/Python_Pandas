# %%
import pandas as pd

# %%
my_file = pd.read_csv('titanic (2).csv')

# %%
my_file.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **RENAMING PASSENGERID COLUMNS**

# %%
my_file.rename(columns = {"PassengerId":"ID"}).head()
# Out:
#    ID  Survived  Pclass                                               Name  \
# 0   1         0       3                            Braund, Mr. Owen Harris
# 1   2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   3         1       3                             Heikkinen, Miss. Laina
# 3   4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   5         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
my_file.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
my_file['Last Name'] = my_file['Name'].str.split(',', expand = True)[0]
my_file.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Last Name
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %% [markdown]
# ## **change the dtype of age columns after filling the nan value with its mean**.

# %%
my_file['Age'].isnull().sum()
# Out:
# 177

# %%
my_file['Age'] = my_file['Age'].fillna(my_file['Age'].mean()).astype('int')
my_file['Age']
# Out:
# 0      22
# 1      38
# 2      26
# 3      35
# 4      35
#        ..
# 886    27
# 887    19
# 888    29
# 889    26
# 890    32
# Name: Age, Length: 891, dtype: int32

# %%
# OR WE CAN CHANGE ON THE SECONED WAY AS WELL...
my_file['Age'] = my_file['Age'].astype('int')
my_file['Age']
# Out:
# 0      22
# 1      38
# 2      26
# 3      35
# 4      35
#        ..
# 886    27
# 887    19
# 888    29
# 889    26
# 890    32
# Name: Age, Length: 891, dtype: int32

# %% [markdown]
# **creating a separate Data Frames for male and female**

# %%
Male_df = my_file[my_file['Sex'] == 'male']
Male_df.head()
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex  Age  \
# 0            1         0       3         Braund, Mr. Owen Harris  male   22
# 4            5         0       3        Allen, Mr. William Henry  male   35
# 5            6         0       3                Moran, Mr. James  male   29
# 6            7         0       1         McCarthy, Mr. Timothy J  male   54
# 7            8         0       3  Palsson, Master. Gosta Leonard  male    2
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked Last Name
# 0      1      0  A/5 21171   7.2500   NaN        S    Braund
# 4      0      0     373450   8.0500   NaN        S     Allen
# 5      0      0     330877   8.4583   NaN        Q     Moran
# 6      0      0      17463  51.8625   E46        S  McCarthy
# 7      3      1     349909  21.0750   NaN        S   Palsson

# %%
Female_df = my_file[my_file['Sex'] == 'female']
Female_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female   14      1
#
#    Parch            Ticket     Fare Cabin Embarked  Last Name
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# 8      2            347742  11.1333   NaN        S    Johnson
# ...

# %%
Female_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          217
# Embarked         2
# Last Name        0
# dtype: int64

# %% [markdown]
# ## **# Average Age of male and female passengers who survived and
# did not survive**d

# %%
Average_male = Male_df.groupby('Survived')
Average_male

# %%
Male_df.groupby('Survived').mean('Age')['Age'].astype(int)
# Out:
# Survived
# 0    30
# 1    27
# Name: Age, dtype: int32

# %%
Average_Gen = my_file.groupby('Survived').mean('Age')['Age'].astype(int)

Average_Gen.rename(index = {0:'DEAD', 1: 'LIVE'})
# Out:
# Survived
# DEAD    30
# LIVE    28
# Name: Age, dtype: int32

# %%
Female_Ave = Female_df.groupby('Survived').mean('Age')['Age'].astype(int)
Female_Ave
# Out:
# Survived
# 0    25
# 1    28
# Name: Age, dtype: int32

# %% [markdown]
# ## **PEOPLE DIED FROM EACH CLASS INDIVIDUALLY**

# %%
People_died = my_file[my_file['Survived']== 0].groupby('Pclass').count()['Survived']
People_died
# Out:
# Pclass
# 1     80
# 2     97
# 3    372
# Name: Survived, dtype: int64

# %% [markdown]
# ## **DROPING TICKET COLUMN**

# %%
my_file.drop('Ticket', axis = 1).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch     Fare Cabin Embarked  Last Name
# 0      0   7.2500   NaN        S     Braund
# 1      0  71.2833   C85        C    Cumings
# 2      0   7.9250   NaN        S  Heikkinen
# 3      0  53.1000  C123        S   Futrelle
# 4      0   8.0500   NaN        S      Allen

# %%
# OR

my_file.drop(columns = ['Ticket']).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch     Fare Cabin Embarked  Last Name
# 0      0   7.2500   NaN        S     Braund
# 1      0  71.2833   C85        C    Cumings
# 2      0   7.9250   NaN        S  Heikkinen
# 3      0  53.1000  C123        S   Futrelle
# 4      0   8.0500   NaN        S      Allen

# %% [markdown]
# ## **AVERAGE MONEY SPEND ON FARE BY MALE AND FEMALE**

# %%
round(Male_df['Fare'].mean(), 2)
# Out:
# 25.52

# %%
Female_df['Fare'].mean()
# Out:
# 44.47981783439491

# %% [markdown]
# ## **MEAN OF THE AGE GROUP WHO TRAVLED IN CLASS 1**

# %%
my_file['Age'].mean()
my_file[['Age','Pclass']]
my_file[my_file['Pclass'] == 1]['Age'].mean()
# Out:
# 36.94444444444444

# %% [markdown]
# ## **ROUND OF FARE COLUMN BY 2 FIGURES**

# %%
my_file.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Last Name
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
round(my_file['Fare'], 2)
# Out:
# 0       7.25
# 1      71.28
# 2       7.92
# 3      53.10
# 4       8.05
#        ...
# 886    13.00
# 887    30.00
# 888    23.45
# 889    30.00
# 890     7.75
# Name: Fare, Length: 891, dtype: float64

# %% [markdown]
# ## **FILL THE CABIN NAN VALUES BY 0**

# %%
my_file['Cabin'] = my_file['Cabin'].fillna(0).head()

# %% [markdown]
# ## **MALE AND FEMALE TRAVELED BY 3rd CLASS**

# %%
my_file[my_file['Pclass'] == 3].groupby('Sex').value_counts(['Pclass'])
# Out:
# Sex     Pclass
# female  3         144
# male    3         347
# Name: count, dtype: int64

# %%
# OR

my_file[my_file['Pclass'] == 3].shape[0]
# Out:
# 491

# %% [markdown]
# ## **people who spent more than 50$ on fare survived**

# %%
my_file.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
#
#    Parch     Ticket     Fare Cabin Embarked Last Name
# 0      0  A/5 21171   7.2500     0        S    Braund
# 1      0   PC 17599  71.2833   C85        C   Cumings

# %%
my_file[(my_file['Fare']>50) & (my_file['Survived'] == 1)].sort_values(by = 'Fare')
my_file[(my_file['Fare']>50) & (my_file['Survived'] == 1)].shape[0]
# Out:
# 109

# %% [markdown]
# ## **people who spent less than 20$ on fare did not survived**

# %%
my_file[(my_file['Fare']<20) & (my_file['Survived'] == 0)].sort_values(by = 'Fare')
# Out:
#      PassengerId  Survived  Pclass  \
# 466          467         0       2
# 263          264         0       1
# 277          278         0       2
# 302          303         0       3
# 413          414         0       2
# ..           ...       ...     ...
# 38            39         0       3
# 18            19         0       3
# 731          732         0       3
# 451          452         0       3
# 490          491         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 466                              Campbell, Mr. William    male   29      0
# 263                              Harrison, Mr. William    male   40      0
# 277                        Parkes, Mr. Francis "Frank"    male   29      0
# 302                    Johnson, Mr. William Cahoone Jr    male   19      0
# 413                     Cunningham, Mr. Alfred Fleming    male   29      0
# ..                                                 ...     ...  ...    ...
# ...

# %% [markdown]
# ## **replacing the values in embarked, s:1,c:2,q:3**

# %%
my_file['Embarked'] = my_file['Embarked'].replace({'S': 1, 'C': 2, 'Q': 3})

# %%
my_file.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin  Embarked  Last Name
# 0      0         A/5 21171   7.2500     0       1.0     Braund
# 1      0          PC 17599  71.2833   C85       2.0    Cumings
# 2      0  STON/O2. 3101282   7.9250     0       1.0  Heikkinen
# 3      0            113803  53.1000  C123       1.0   Futrelle
# ...

# %% [markdown]
# ## **persons whose age was greater than 50 spend more than 50$ on fare**

# %%
Old_age_spending_money = my_file[(my_file['Age'] > 50) & (my_file['Fare'] > 50)].shape[0]
Old_age_spending_money
# Out:
# 21

# %% [markdown]
# **filling the nan in embarked column(if present) by the most repeated
# lette**r

# %%
most_repeated_values = my_file['Embarked'].mode().astype('int')
most_repeated_values
# Out:
# 0    1
# Name: Embarked, dtype: int32

# %%
my_file['Embarked'].fillna(most_repeated_values)
my_file.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin  Embarked  Last Name
# 0      0         A/5 21171   7.2500     0       1.0     Braund
# 1      0          PC 17599  71.2833   C85       2.0    Cumings
# 2      0  STON/O2. 3101282   7.9250     0       1.0  Heikkinen
# 3      0            113803  53.1000  C123       1.0   Futrelle
# ...

# %% [markdown]
# ## **calling 20 random rows from the df**

# %%
my_file.sample(n = 20)
# Out:
#      PassengerId  Survived  Pclass  \
# 635          636         1       2
# 38            39         0       3
# 830          831         1       3
# 730          731         1       1
# 272          273         1       2
# 247          248         1       2
# 226          227         1       2
# 47            48         1       3
# 710          711         1       1
# 664          665         1       3
# 169          170         0       3
# 474          475         0       3
# 882          883         0       3
# 734          735         0       2
# 457          458         1       1
# 694          695         0       1
# 764          765         0       3
# 9             10         1       2
# 89            90         0       3
# 401          402         0       3
#
#                                                  Name     Sex  Age  SibSp  \
# 635                                 Davis, Miss. Mary  female   28      0
# ...

# %% [markdown]
# ## **new column in this df with & quot;passenger of titanic & quot; phrase common for all rows**

# %%
my_file['PASSENGER'] = 'Passengers of Titanic'
my_file.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin  Embarked  Last Name  \
# 0      0         A/5 21171   7.2500     0       1.0     Braund
# 1      0          PC 17599  71.2833   C85       2.0    Cumings
# 2      0  STON/O2. 3101282   7.9250     0       1.0  Heikkinen
# 3      0            113803  53.1000  C123       1.0   Futrelle
# ...

# %% [markdown]
# ## **call rows starting from 100 to 200 and concat them to a seperate df made with rows 20 to 50 index and name the df “concat_df”**

# %%
row_100_200 = my_file.iloc[100:201]
row_20_50 = my_file.iloc[20:51]
row_20_50.head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 20           21         0       2           Fynney, Mr. Joseph J    male   35
# 21           22         1       2          Beesley, Mr. Lawrence    male   34
# 22           23         1       3    McGowan, Miss. Anna "Annie"  female   15
# 23           24         1       1   Sloper, Mr. William Thompson    male   28
# 24           25         0       3  Palsson, Miss. Torborg Danira  female    8
#
#     SibSp  Parch  Ticket     Fare Cabin  Embarked Last Name  \
# 20      0      0  239865  26.0000   NaN       1.0    Fynney
# 21      0      0  248698  13.0000   NaN       1.0   Beesley
# 22      0      0  330923   8.0292   NaN       3.0   McGowan
# 23      0      0  113788  35.5000   NaN       1.0    Sloper
# 24      3      1  349909  21.0750   NaN       1.0   Palsson
#
#                 PASSENGER
# 20  Passengers of Titanic
# 21  Passengers of Titanic
# 22  Passengers of Titanic
# ...

# %%
concat_df = pd.concat([row_100_200, row_20_50]).sort_values(by = 'PassengerId')
concat_df
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 20            21         0       2                    Fynney, Mr. Joseph J
# 21            22         1       2                   Beesley, Mr. Lawrence
# 22            23         1       3             McGowan, Miss. Anna "Annie"
# 23            24         1       1            Sloper, Mr. William Thompson
# 24            25         0       3           Palsson, Miss. Torborg Danira
# ..           ...       ...     ...                                     ...
# 196          197         0       3                     Mernagh, Mr. Robert
# 197          198         0       3        Olsen, Mr. Karl Siegwart Andreas
# 198          199         1       3        Madigan, Miss. Margaret "Maggie"
# 199          200         0       2  Yrois, Miss. Henriette ("Mrs Harbeck")
# 200          201         0       3          Vande Walle, Mr. Nestor Cyriel
#
# ...
